# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Iris.csv")
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.iloc[0]
# Out:
# Id                         1
# SepalLengthCm            5.1
# SepalWidthCm             3.5
# PetalLengthCm            1.4
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 0, dtype: object

# %%
data.shape
# Out:
# (150, 6)

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
data['SepalWidthCm'].value_counts()
# Out:
# SepalWidthCm
# 3.0    26
# 2.8    14
# 3.2    13
# 3.1    12
# 3.4    12
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.6     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: count, dtype: int64

# %%
data['SepalLengthCm'].value_counts()
# Out:
# SepalLengthCm
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: count, dtype: int64

# %%
 data['PetalLengthCm'].value_counts()
# Out:
# PetalLengthCm
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: count, dtype: int64

# %%
 data['PetalWidthCm'].value_counts()
# Out:
# PetalWidthCm
# 0.2    28
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# 0.3     7
# 0.1     6
# 2.1     6
# 2.0     6
# 1.2     5
# 1.9     5
# 1.6     4
# 2.5     3
# 2.2     3
# 2.4     3
# 1.1     3
# 1.7     2
# 0.6     1
# 0.5     1
# Name: count, dtype: int64

# %%
 data['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %%
data.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %% [markdown]
# #there is no null data

# %%
duplicates = data.duplicated(keep=False)
duplicates
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Length: 150, dtype: bool

# %%
#false means there is no duplicate data is present

# %%
duplicates = data[data.duplicated(keep=False)]

if duplicates.empty:
    print("No duplicate rows found.")
else:
    print("Duplicate rows:")
    print(duplicates)
# Out:
# No duplicate rows found.

# %%
# in above cell you can see there is no duplicate row is present

# %%
# data visulization

# %%
train=data = pd.read_csv("Iris.csv")
sns.countplot(x='Species', data=train)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
sns.countplot(x='SepalWidthCm', data=train)
# Out:
# <Axes: xlabel='SepalWidthCm', ylabel='count'>

# %%
sns.countplot(x='SepalLengthCm', data=train)
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='count'>

# %%
data["SepalWidthCm"].hist()
# Out:
# <Axes: >

# %%
data["SepalLengthCm"].hist()
# Out:
# <Axes: >

# %%
data["PetalLengthCm"].hist()
# Out:
# <Axes: >

# %%
data["PetalWidthCm"].hist()
# Out:
# <Axes: >

# %%
data["Species"].hist()
# Out:
# <Axes: >

# %%
plt.hist(
    [data['PetalWidthCm'], data['SepalLengthCm'], data['PetalLengthCm'], data['SepalWidthCm']], 
    bins=30, 
    stacked=True, 
    color=['cyan', 'purple', 'green', 'orange'], 
    edgecolor='black'
)

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Distribution of PetalWidthCm, SepalLengthCm, PetalLengthCm, and SepalWidthCm')

# Adding legend
plt.legend(['PetalWidthCm', 'SepalLengthCm', 'PetalLengthCm', 'SepalWidthCm'])

# Display the plot
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the iris dataset
df = pd.read_csv('iris.csv')

# Function to plot histograms for each column
def plotPerColumnDistribution(df, n_rows, n_cols):
    """Plots histograms for each column in a DataFrame.

    Args:
        df: The DataFrame to plot.
        n_rows: The number of rows in the subplot grid.
        n_cols: The number of columns in the subplot grid.
    """
    fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(16, 8))

    # Flatten the axes array for easier iteration
    axes = axes.flatten()

    # Loop through each column and plot a histogram
    for i, col in enumerate(df.columns):
        axes[i].hist(df[col], bins=10)
        axes[i].set_title(f"{col} (column {i})")
        axes[i].set_xlabel("Value")
        axes[i].set_ylabel("Counts")
        axes[i].grid(True)

    # Remove any unused subplots
    plt.tight_layout()
    plt.show()

# Call the function to generate the histograms
plotPerColumnDistribution(df, 3, 2)

# %%
plotPerColumnDistribution(df, 3, 2)

# %%
plt.hist([data['SepalWidthCm'], data['SepalLengthCm']], bins=30, stacked=True, color=['cyan', 'purple'], edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Distribution of SepalWidthCm and SepalLengthCm')

# Adding legend
plt.legend(['SepalWidthCm', 'SepalLengthCm'])

# Display the plot
plt.show()

# %%
plt.hist([data['PetalLengthCm'], data['PetalWidthCm']], bins=30, stacked=True, color=['cyan', 'purple'], edgecolor='black')

# Adding labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Distribution of PetalLengthCm and PetalWidthCm')

# Adding legend
plt.legend(['PetalLengthCm', 'PetalWidthCm'])

# Display the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing 'SepalLengthCm' and 'SepalWidthCm' columns

plt.figure()
plt.scatter(df['SepalLengthCm'], df['SepalWidthCm'], label='SepalLengthCm vs SepalWidthCm', color='blue')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.title('SepalLengthCm vs SepalWidthCm')
plt.legend()
plt.grid(True)  # Adding grid lines for better readability
plt.show()

# %%
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing 'SepalLengthCm' and 'SepalWidthCm' columns

# Creating a condition to differentiate points based on a threshold (example)
threshold = df['SepalLengthCm'].mean()

plt.figure()
plt.scatter(df[df['SepalLengthCm'] >= threshold]['SepalLengthCm'], 
            df[df['SepalLengthCm'] >= threshold]['SepalWidthCm'], 
            label='SepalLengthCm >= Threshold', color='blue')
plt.scatter(df[df['SepalLengthCm'] < threshold]['SepalLengthCm'], 
            df[df['SepalLengthCm'] < threshold]['SepalWidthCm'], 
            label='SepalLengthCm < Threshold', color='red')
plt.xlabel('SepalLengthCm')
plt.ylabel('SepalWidthCm')
plt.title('SepalLengthCm vs SepalWidthCm')
plt.legend()
plt.grid(True)  # Adding grid lines for better readability
plt.show()
